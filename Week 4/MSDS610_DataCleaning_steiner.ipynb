# %% [markdown]
# <img align="right" style="padding-left:50px;" src="figures_wk4/data_cleaning.png" width=350><br>
# ### User Bias in Data Cleaning
# For your homework assignment this week, we will explore how our treatment of our data can impact the quality of our results.
#
# **Dataset:**
# The data is a Salary Survey from AskAManager.org. It’s US-centric-ish but does allow for a range of country inputs.
#
# A list of the corresponding survey questions can be found [here](https://www.askamanager.org/2021/04/how-much-money-do-you-make-4.html).

# %%
import pandas as pd

# %%
df= pd.read_csv('survey_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28108 entries, 0 to 28107
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  28108 non-null  object
#  1   q1         28108 non-null  object
#  2   q2         28033 non-null  object
#  3   q3         28107 non-null  object
#  4   q4         7273 non-null   object
#  5   q5         28108 non-null  object
#  6   q6         20793 non-null  float64
#  7   q7         28108 non-null  object
#  8   q8         211 non-null    object
#  9   q9         3047 non-null   object
#  10  q10        28108 non-null  object
#  11  q11        23074 non-null  object
#  12  q12        28026 non-null  object
#  13  q13        28108 non-null  object
#  14  q14        28108 non-null  object
#  15  q15        27885 non-null  object
#  16  q16        27937 non-null  object
#  17  q17        27931 non-null  object
# dtypes: float64(1), object(17)
# memory usage: 3.9+ MB

# %%
df.head()
# Out:
#             timestamp     q1                             q2  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                          q3   q4      q5      q6   q7   q8  \
# 0        Research and Instruction Librarian  NaN  55,000     0.0  USD  NaN
# 1  Change & Internal Communications Manager  NaN  54,600  4000.0  GBP  NaN
# 2                      Marketing Specialist  NaN  34,000     NaN  USD  NaN
# 3                           Program Manager  NaN  62,000  3000.0  USD  NaN
# 4                        Accounting Manager  NaN  60,000  7000.0  USD  NaN
#
#     q9             q10             q11          q12           q13  \
# 0  NaN   United States   Massachusetts       Boston     5-7 years
# ...

# %% [markdown]
# ### Assignment
# Your goal for this assignment is to observe how your data treatment during the cleaning process can skew or bias the dataset.
#
# Before diving right in, stop and read through the questions associated with the dataset. As you can see, they are either free-form text entries or categorical selections. Knowing this, perform some exploratory data analysis (EDA) to investigate the "state" of the dataset.
#
# [Add as many code cell below here as needs]

# %% [markdown]
# <div class="alert alert-block alert-info">
# Just putting a break into things so it's easier to figure out what is what and to draw the eye to it.

# %%
total = df.isnull().sum().sort_values(ascending=False)
total
# Out:
# q8           27897
# q9           25061
# q4           20835
# q6            7315
# q11           5034
# q15            223
# q17            177
# q16            171
# q12             82
# q2              75
# q3               1
# q7               0
# q5               0
# q1               0
# q10              0
# q13              0
# q14              0
# timestamp        0
# dtype: int64

# %%
df_marg=df.groupby(['q17', 'q16'])['q16'].count().reset_index(name='GenderCount')
df_marg=df_marg.sort_values(by='GenderCount', ascending=False).reset_index()
df_marg
# Out:
#      index                                                q17         q16  \
# 0      106                                              White       Woman
# 1      103                                              White         Man
# 2        8                            Asian or Asian American       Woman
# 3      104                                              White  Non-binary
# 4       43                          Black or African American       Woman
# ..     ...                                                ...         ...
# 106     12  Asian or Asian American, Black or African Amer...  Non-binary
# 107     81  Hispanic, Latino, or Spanish origin, White, An...  Non-binary
# 108     53  Black or African American, Middle Eastern or N...       Woman
# 109     83                 Middle Eastern or Northern African  Non-binary
# 110     21  Asian or Asian American, Hispanic, Latino, or ...  Non-binary
#
#      GenderCount
# 0          17931
# 1           4473
# 2           1021
# ...

# %%
df_ed=df.groupby(['q15', 'q16'])['q16'].count().reset_index(name='EduCount')
df_ed=df_ed.sort_values(by='EduCount', ascending=False).reset_index()
df_ed
# Out:
#     index                                 q15                            q16  \
# 0       3                      College degree                          Woman
# 1      11                     Master's degree                          Woman
# 2       0                      College degree                            Man
# 3       8                     Master's degree                            Man
# 4      24                        Some college                          Woman
# 5      16                                 PhD                          Woman
# 6      20  Professional degree (MD, JD, etc.)                          Woman
# 7      21                        Some college                            Man
# 8       1                      College degree                     Non-binary
# 9       7                         High School                          Woman
# 10     12                                 PhD                            Man
# ...

# %%
df['q16'].value_counts()
# Out:
# q16
# Woman                            21389
# Man                               5502
# Non-binary                         747
# Other or prefer not to answer      298
# Prefer not to answer                 1
# Name: count, dtype: int64

# %%
df.q17.value_counts()
# Out:
# q17
# White                                                                                                                                                                                                                           23235
# Asian or Asian American                                                                                                                                                                                                          1410
# Black or African American                                                                                                                                                                                                         694
# Another option not listed here or prefer not to answer                                                                                                                                                                            625
# ...

# %%
df.q1.value_counts()
# Out:
# q1
# 25-34         12668
# 35-44          9908
# 45-54          3193
# 18-24          1236
# 55-64           994
# 65 or over       95
# under 18         14
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Question:** How would you describe the "state" of this dataset? Be specific and detailed in your answer. (Think paragraphs rather than sentences).

# %% [markdown]
# This data set is meant to represent the salary made by those who enter their data.  It is self reported.  <p>
# The data is entered in either free form or by radio button.  In some instances the end user can select multiple radio buttons.
# <p>
# Initial impression of the 'state of the data':  the data is definitely dirty.  It appears that every single record has at least 1 null in it.  It is also evident that due to the free form entering, grouping the data will be difficult due to misspellings, differences in abbreviations (i.e. USA, US, U.S.A., U.S.), differences in capitalization (i.e. us, US), added information in the text fields (i.e. AUD (austrailian dollars), czek money).  With the exception of 2 features in the data, everything is an object, which will not lend itself easily to graphing or visual representation of the data.  Age (q1) has been pre grouped, and appears to have no nulls present.  While this field is a text field, it can be converted to a corresponding number for a better idea of the age groups that responded to the survey.  The data also has a field for how long the respondent has been working and one for how long they've been working in their field.  Like the age field, this will need to be converted to a numeric value before it will be useful in graphing.
# <p>
# The gender (q16) feature demonstrates that there is an extreme imbalance between women and the rest of the genders.  This will create a skewed end result for any analysis or modeling that will be done with this data.  Moreover, the counts indicate that white women dominate this data set.  In reviewing the counts grouped with education level, it is evident that the women who responded to the survey also have a fairly high level of education.
# <p>
# Prior to use, this data set will need the nulls cleaned up.  After the nulls are cleaned up, it might be helpful to clean up other text features (fix spelling and abbreviations).

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Now, it is time to plan how you will clean up the dataset. You **are not** allowed to use any machine learning technique to clean the data. (No SMOTE! No machine learning! Or anything like that!)
#
# **Question:** Based on your EDA above, detail how you would clean up this dataset.
# Things to consider: (This is not an exhaustive list)
# - Are there columns that can't be effectively cleaned? If so, why?
# - Are there columns that genuinely won't have a data value?
# - Does it make sense to segment the dataset based on specific columns when determining how to handle the missing values?
# - Are outliers a factor in this dataset?
#
# Remember preserving as much of the data as possible is the goal. That means dropping rows with a missing value somewhere might not be the best idea.
#
# [Add you answer to this markdown cell]

# %% [markdown]
# <b>  Based on the question page: </b>
# <br>Q2 is the industry someone works in.  The nulls in this could be safely renamed as 'Other'  or 'Unknown', rather than deleting those 75 records.
# <br>Q3 is a required field.  Not sure how a null snuck in.  This could likely be dropped without disrupting the data too much
# <br>Q4 is additional job title context.  This null in most records--only 8k of the records have a value here.  The data can be explored. however, it's not a required field and we can probably move forward without it.
# <br>Q6 is additional compensation.  There are 7k null values.  This can be imputed to 0.  It may not be 100% accurate, yet, it is safer than using the mean/median of the other records.
# <br>Q8 is currency not listed.  This should be looked at for distinct values.  It is likely that we can replace 'Other' in Q7 with this value.  If Q8 has too many values or has values that are nonsensical, we should be able to drop it without too much consequence.
# <br>Q9 This is additional info about income. There's only approx 3k records with data.  Review what is there and see if it can be combined with another field.  If not, pretty sure it can be dropped.
# <br>Q11 This is the state that the respondent works in.  Not a required field and many foreign countries don't have states or provinces.  I'll need to verify that the Nulls are indeed for foregin locations.  If they aren't, I should be able to fill in the null based on Q12.  If they are, I should be able to safely set this to 'Unknown', since there are only 5k that are null.
# <br>Q12 This is the city where the respondant works.  It is a required field, yet we still have 82 of them.  I'll need to look at the records themselves to see if those can be dropped.
# <br>Q15 Highest level of education.  I can replace nulls with 'unknown'.
# <br>Q16 Gender.  This can be set to 'Other or prefer not to answer'
# <br>Q17 Race.  This can be set to 'Another option not listed here or prefer not to answer'.
# <p>
#
# Possible analysis directions:
# <br>***may need to convert wages to USD to accommodate for different currency type
# <br>Wages by industry
# <br>Wages by job title
# <br>Wages by Country/State
# <br>Wages by city
# <br>Wages Education
# <br>Wages by Gender
# <br>Wages by Race
# <br>Wages by Age group
# <p>
# Other EDA
# <br>Counts by Gender, by Race, age group.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Based on the plan the you described above, go ahead and clean up the dataset.
#
# [Add as many code cell below here as needs]

# %% [markdown]
# Bring in the packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# %% [markdown]
# address q2 and set the values to Other: Unknown

# %%
df['q2'].value_counts()
# Out:
# q2
# Computing or Tech                          4711
# Education (Higher Education)               2466
# Nonprofits                                 2420
# Health care                                1899
# Government and Public Administration       1893
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Social networks                               1
# Name: count, Length: 1220, dtype: int64

# %%
df['q2'] = df['q2'].fillna('Other: Unknown')

# %% [markdown]
# review the record that has q3 null to confirm it can be dropped

# %%
df[df['q3'].isnull()]
# Out:
#                  timestamp     q1  \
# 27996  11/29/2023 19:59:34  18-24
#
#                                                  q2   q3  \
# 27996  I'm currently a student and don't have a job  NaN
#
#                                q4 q5   q6   q7   q8  \
# 27996  I don't have one right now  0  0.0  USD  NaN
#
#                                  q9    q10           q11  q12          q13  \
# 27996  There is no income right now  U.S.A  Pennsylvania  NaN  2 - 4 years
#
#                q14           q15  q16                        q17
# 27996  2 - 4 years  Some college  Man  Black or African American

# %% [markdown]
# This record doesn't add enough of the dataset to keep it.  We can drop the record safely.

# %%
df.dropna(subset = ['q3'])
# Out:
#                  timestamp     q1                             q2  \
# 0       4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1       4/27/2021 11:02:22  25-34              Computing or Tech
# 2       4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3       4/27/2021 11:02:41  25-34                     Nonprofits
# 4       4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                    ...    ...                            ...
# 28103  12/29/2024 23:50:26  25-34                  Entertainment
# 28104    1/3/2025 16:03:10  18-24   Engineering or Manufacturing
# 28105   1/16/2025 10:00:47  35-44                  Entertainment
# 28106   1/23/2025 19:38:04  35-44                     Nonprofits
# 28107   1/27/2025 21:02:19  45-54              Computing or Tech
#
#                                                    q3   q4       q5       q6  \
# 0                  Research and Instruction Librarian  NaN   55,000      0.0
# ...

# %% [markdown]
# check q4 to see what it actually adds to the dataset and if we can reasonably drop it

# %%
df[df['q4'].notnull()]
# Out:
#                  timestamp     q1                                    q2  \
# 7       4/27/2021 11:03:00  25-34         Education (Primary/Secondary)
# 8       4/27/2021 11:03:01  45-54                     Computing or Tech
# 13      4/27/2021 11:03:10  25-34                                   Law
# 26      4/27/2021 11:03:38  25-34                            Nonprofits
# 35      4/27/2021 11:03:55  35-44          Education (Higher Education)
# ...                    ...    ...                                   ...
# 28093   11/18/2024 7:24:09  45-54                     Computing or Tech
# 28094  11/18/2024 11:08:58  18-24                     Computing or Tech
# 28095  11/22/2024 15:35:09  25-34                  Hospitality & Events
# 28097   12/5/2024 17:12:41  25-34         Education (Primary/Secondary)
# 28099   12/6/2024 19:52:27  35-44  Government and Public Administration
#
#                               q3  \
# 7                      Librarian
# ...

# %%
#it looks like it is safe to drop the column.  While the data is interesting, it won't add a lot to analysis
df.drop('q4', axis=1, inplace=True)

# %% [markdown]
# q5 holds the salary data.  q6 is additional compensation.  Once we've dealt q6, we can deal with q5

# %%
df[df['q6'].notnull()]
# Out:
#                  timestamp     q1                                    q2  \
# 0       4/27/2021 11:02:10  25-34          Education (Higher Education)
# 1       4/27/2021 11:02:22  25-34                     Computing or Tech
# 3       4/27/2021 11:02:41  25-34                            Nonprofits
# 4       4/27/2021 11:02:42  25-34         Accounting, Banking & Finance
# 6       4/27/2021 11:02:51  25-34                            Publishing
# ...                    ...    ...                                   ...
# 28099   12/6/2024 19:52:27  35-44  Government and Public Administration
# 28100  12/11/2024 14:53:19  25-34                           Health care
# 28102   12/20/2024 6:16:27  55-64  Government and Public Administration
# 28104    1/3/2025 16:03:10  18-24          Engineering or Manufacturing
# 28107   1/27/2025 21:02:19  45-54                     Computing or Tech
#
#                                              q3        q5         q6     q7  \
# ...

# %% [markdown]
# replace the nulls with 0, convert q5 to float and then create a new column that is q5+q6

# %%
df['q6'] = df['q6'].fillna(0)

# %%
df['q5'] = df['q5'].apply(lambda x : x.replace(',','')).astype(float)

# %%
df['Totalq5']=df['q5']+df['q6']

# %% [markdown]
# q8 reflects the monetary denomination.  This is a free form text field that appears to be all over in terms of what has been entered.  Cleaning that up will allow for easier grouping and segregation of compensation types.

# %%
df[df['q8'].notnull()]
# Out:
#                  timestamp     q1                                         q2  \
# 434     4/27/2021 11:09:54  25-34                          Computing or Tech
# 603     4/27/2021 11:12:24  45-54                                Health care
# 752     4/27/2021 11:14:29  45-54  Public Library (technically City Govt.?)
# 766     4/27/2021 11:14:39  25-34                          Recruitment or HR
# 776     4/27/2021 11:14:45  45-54               Education (Higher Education)
# ...                    ...    ...                                        ...
# 28077   9/19/2024 19:16:28  25-34                                Social Work
# 28093   11/18/2024 7:24:09  45-54                          Computing or Tech
# 28096   11/24/2024 8:08:37  25-34                     Business or Consulting
# 28100  12/11/2024 14:53:19  25-34                                Health care
# 28105   1/16/2025 10:00:47  35-44                              Entertainment
#
# ...

# %%
df[ (df['q7'] =='Other') & (df['q8'].isnull()) ]
# Out:
#                 timestamp     q1                                    q2  \
# 9344   4/27/2021 17:44:22  45-54  Government and Public Administration
# 18843   4/29/2021 3:50:24  18-24                           Health care
# 18882   4/29/2021 4:30:05  25-34                     Computing or Tech
# 18904   4/29/2021 4:59:14  45-54                               Mining
# 27959  4/29/2023 15:24:07  18-24          Engineering or Manufacturing
#
#                             q3       q5   q6     q7   q8   q9            q10  \
# 9344   Contracts Administrator  76000.0  0.0  Other  NaN  NaN  United States
# 18843   Microbiologist officer  48000.0  0.0  Other  NaN   RM       Malaysia
# 18882             Data Analyst  97000.0  0.0  Other  NaN  NaN       Malaysia
# 18904          Office manager   55140.0  0.0  Other  NaN  NaN           USA
# 27959            Data Engineer  10000.0  0.0  Other  NaN  NaN          India
#
#               q11           q12             q13             q14  \
# ...

# %%
df.loc[9344, 'q7'] = 'USD'
df.loc[18904, 'q7'] = 'USD'
df.loc[27959, 'q7'] = 'RUP'
df.loc[18843, 'q7'] = 'RM'
df.loc[18882, 'q7'] = 'RM'

# %%
df.loc[df["q8"] == "Indian rupees", "q7"] = "RUP"
df.loc[df["q8"] == "Rupees", "q7"] = "RUP"
df.loc[df["q8"] == "US Dollar", "q7"] = "USD"
df.loc[df["q8"] == "American Dollars", "q7"] = "USD"
df.loc[df["q8"] == "NIS (new Israeli shekel)", "q7"] = "NIS"
df.loc[df["q8"] == "PLN (Polish zloty)", "q7"] = "PLN"

# %%
df.loc[df["q8"] == "Norwegian kroner (NOK)", "q7"] = "NOK"
df.loc[df["q8"] == "RMB (chinese yuan)", "q7"] = "RMB"
df.loc[df["q8"] == "KRW (Korean Won)", "q7"] = "KRW"
df.loc[df["q8"] == "ILS (Shekel)", "q7"] = "ILS"
df.loc[df["q8"] == "China RMB", "q7"] = "RMB"
df.loc[df["q8"] == "AUD Australian", "q7"] = "AUD"
df.loc[df["q8"] == "PLN (Zwoty)", "q7"] = "PLN"
df.loc[df["q8"] == "czech crowns", "q7"] = "CZK"
df.loc[df["q8"] == "Mexican pesos", "q7"] = "MXN"

# %%
df.loc[df["q8"] == "Peso Argentino", "q7"] = "ARS"
df.loc[df["q8"] == "Philippine Peso", "q7"] = "PHP"
df.loc[df["q8"] == "Taiwanese dollars", "q7"] = "TWD"
df.loc[df["q8"] == "THAI BAHT", "q7"] = "THB"
df.loc[df["q8"] == "AUD Australian", "q7"] = "AUD"
df.loc[df["q8"] == "Polish Złoty", "q7"] = "PLN"
df.loc[df["q10"] == "Australia", "q8"] = "AUD"
df.loc[df["q8"] == "Philippine peso (PHP)", "q7"] = "PHP"

# %%
df['q7'] = df.apply(lambda x: x['q8'] if str(x['q8'])in ['THB','Bdt','ZAR','RUP','ARS','Php','PLN','CNY','ILS/NIS','AUD','BRL','IDR','Sgd','NZD','DKK'] else x['q7'], axis=1)

# %%
df['q7'] = df.apply(lambda x: x['q8'] if str(x['q8'])in ['MXN','NIS','ZAR','RMB','TWD','PHP','KRW','IDR','Nok','ILS','DKK','IDR','LKR','NZD','SAR'] else x['q7'], axis=1)

# %%
df['q7'] = df.apply(lambda x: x['q8'] if str(x['q8'])in ['USD', 'MYR', 'CHF','NOK','INR','SGD','USD','SEK','EUR','BR$','TRY','DKK','Dkk','NGN','COP','TTD','TZS','Czk','CZK','GBP','PLN','RUP','BRL (R$)'] else x['q7'], axis=1)

# %%
df.loc[11454, 'q7'] = 'IDR'
df.loc[11737, 'q7'] = 'DKK'
df.loc[13218, 'q7'] = 'AUD'
df.loc[14915, 'q7'] = 'USD'
df.loc[16395, 'q7'] = 'ARS'
df.loc[16627, 'q7'] = 'ILS'
df.loc[17113, 'q7'] = 'PHP'
df.loc[18930, 'q7'] = 'RM'

# %%
df.loc[19250, 'q7'] = 'ARS'
df.loc[19323, 'q7'] = 'PHP'
df.loc[21322, 'q7'] = 'INR'
df.loc[21350, 'q7'] = 'NTD'
df.loc[21545, 'q7'] = 'DKK'
df.loc[22826, 'q7'] = 'CAD'
df.loc[22871, 'q7'] = 'KRW'
df.loc[23123, 'q7'] = 'DKK'
df.loc[24198, 'q7'] = 'EUR'
df.loc[24843, 'q7'] = 'SGD'

# %%
df.loc[24884, 'q7'] = 'NTD'
df.loc[24949, 'q7'] = 'MXN'
df.loc[25548, 'q7'] = 'THB'
df.loc[26424, 'q7'] = 'THB'
df.loc[28096, 'q7'] = 'RUP'
df.loc[27834, 'q7'] = 'SGD'
df.loc[27191, 'q7'] = 'HRK'
df.loc[20373, 'q7'] = 'ILS'

# %%
df[ (df['q7'] =='Other') ]
# Out:
# Empty DataFrame
# Columns: [timestamp, q1, q2, q3, q5, q6, q7, q8, q9, q10, q11, q12, q13, q14, q15, q16, q17, Totalq5]
# Index: []

# %% [markdown]
# Now that Other has been updated, we can drop q8

# %%
df.drop('q8', axis=1, inplace=True)

# %%
df[df['q9'].notnull()]
# Out:
#                  timestamp          q1                                    q2  \
# 9       4/27/2021 11:03:02       35-44         Accounting, Banking & Finance
# 32      4/27/2021 11:03:45       25-34         Accounting, Banking & Finance
# 44      4/27/2021 11:04:04       25-34                     Computing or Tech
# 62      4/27/2021 11:04:29  65 or over              Property or Construction
# 65      4/27/2021 11:04:33       25-34          Education (Higher Education)
# ...                    ...         ...                                   ...
# 28069   9/10/2024 23:58:45       35-44                     Computing or Tech
# 28078   9/23/2024 17:40:20       18-24              Leisure, Sport & Tourism
# 28093   11/18/2024 7:24:09       45-54                     Computing or Tech
# 28099   12/6/2024 19:52:27       35-44  Government and Public Administration
# 28100  12/11/2024 14:53:19       25-34                           Health care
#
# ...

# %% [markdown]
# q9 is additional info about the respondents compensation is for.  This doesn't add a lot to the data set.  It should be safe to drop it

# %%
df.drop('q9', axis=1, inplace=True)

# %%
df[df['q11'].isnull()]
# Out:
#                  timestamp     q1                                    q2  \
# 1       4/27/2021 11:02:22  25-34                     Computing or Tech
# 10      4/27/2021 11:03:03  25-34                            Nonprofits
# 14      4/27/2021 11:03:11  18-24                           Health care
# 15      4/27/2021 11:03:11  35-44        Utilities & Telecommunications
# 21      4/27/2021 11:03:24  35-44                            Nonprofits
# ...                    ...    ...                                   ...
# 28096   11/24/2024 8:08:37  25-34                Business or Consulting
# 28098    12/6/2024 5:45:00  18-24                        Other: Unknown
# 28100  12/11/2024 14:53:19  25-34                           Health care
# 28102   12/20/2024 6:16:27  55-64  Government and Public Administration
# 28105   1/16/2025 10:00:47  35-44                         Entertainment
#
#                                                    q3          q5         q6  \
# ...

# %% [markdown]
# q11 is the state the respondent works in, if applicable.  In some cases, the state is present in q12, however, it doesn't make sense to go through 5034 records to see which ones have the state in the city feature.  We can set it to unknown.  Same is true for q12.

# %%
df['q11'] = df['q11'].fillna('Unknown')

# %%
df[df['q12'].isnull()]
# Out:
#                  timestamp        q1  \
# 148     4/27/2021 11:05:54     25-34
# 700     4/27/2021 11:13:46     25-34
# 904     4/27/2021 11:16:49     45-54
# 944     4/27/2021 11:17:32     35-44
# 1396    4/27/2021 11:24:58     35-44
# ...                    ...       ...
# 27248  10/26/2021 13:43:53     18-24
# 27901   11/15/2022 4:28:09     55-64
# 27972   8/21/2023 22:47:22  under 18
# 27996  11/29/2023 19:59:34     18-24
# 28020   3/19/2024 17:40:39     25-34
#
#                                                  q2  \
# 148                    Education (Higher Education)
# 700                                       Libraries
# 904                               Computing or Tech
# 944            Government and Public Administration
# 1396           Government and Public Administration
# ...                                             ...
# 27248                                      Science
# 27901                                   Health care
# ...

# %%
df['q12'] = df['q12'].fillna('Unknown')

# %%
df[df['q15'].isnull()]
# Out:
#                 timestamp     q1                              q2  \
# 13     4/27/2021 11:03:10  25-34                             Law
# 24     4/27/2021 11:03:31  25-34                  Public Library
# 192    4/27/2021 11:06:27  35-44    Education (Higher Education)
# 241    4/27/2021 11:07:12  35-44                           Sales
# 659    4/27/2021 11:13:14  45-54  Utilities & Telecommunications
# ...                   ...    ...                             ...
# 28035  4/23/2024 23:39:34  18-24    Education (Higher Education)
# 28043   5/27/2024 2:47:26  25-34               Computing or Tech
# 28049  6/28/2024 14:00:00  25-34    Education (Higher Education)
# 28053  7/12/2024 18:23:10  18-24                      Nonprofits
# 28089  11/11/2024 7:28:08  18-24     Marketing, Advertising & PR
#
#                                q3         q5      q6   q7             q10  \
# 13       Legal Aid Staff Attorney    52000.0     0.0  USD   United States
# ...

# %% [markdown]
# There's a relatively low number of records that have no value for education.  These can be set to Unknown.
# <br>
# For q16 (gender), we can safely set the nulls to Other or Prefer not to answer
# <br> For q17 (race) we can safely set the nulls to Another option not listed here or prefer not to answer

# %%
df['q15'] = df['q15'].fillna('Unknown')

# %%
df['q16'] = df['q16'].fillna('Other or prefer not to answer')

# %%
df['q17'] = df['q17'].fillna('Another option not listed here or prefer not to answer')

# %% [markdown]
# Okay, nulls have been taken care of.

# %%
df.q10.value_counts()
# Out:
# q10
# United States      9004
# USA                7946
# US                 2612
# Canada             1572
# United States       668
#                    ...
# IS                    1
# United Kingdomk       1
#  New Zealand          1
# Cuba                  1
# Česká republika       1
# Name: count, Length: 382, dtype: int64

# %%
df.loc[df["q10"] == "United States", "q10"] = "USA"

# %%
df.loc[df["q10"] == "US", "q10"] = "USA"

# %%
df.loc[df["q10"] == "United States ", "q10"] = "USA"
df.loc[df["q10"] == "United states", "q10"] = "USA"
df.loc[df["q10"] == "United statew", "q10"] = "USA"
df.loc[df["q10"] == "For the United States government, but posted overseas", "q10"] = "USA"
df.loc[df["q10"] == "U.S.", "q10"] = "USA"
df.loc[df["q10"] == "USA ", "q10"] = "USA"
df.loc[df["q10"] == "Usa", "q10"] = "USA"
df.loc[df["q10"] == "usa", "q10"] = "USA"
df.loc[df["q10"] == "United States of America", "q10"] = "USA"
df.loc[df["q10"] == "United Kingdom", "q10"] = "UK"
df.loc[df["q10"] == "Englang", "q10"] = "UK"
df.loc[df["q10"] == "Wales (United Kingdom)", "q10"] = "UK"
df.loc[df["q10"] == "United Kingdomk", "q10"] = "UK"
df.loc[df["q10"] == "New Zealand", "q10"] = "NZ"
df.loc[df["q10"] == " New Zealand", "q10"] = "NZ"
df.loc[df["q10"] == "England, Gb", "q10"] = "UK"
df.loc[df["q10"] == "Canada", "q10"] = "CAN"
df.loc[df["q10"] == "Australia", "q10"] = "AUS"

# %%
df.q10.value_counts()
# Out:
# q10
# USA                22551
# CAN                 1572
# UK                  1126
# AUS                  318
# Germany              174
#                    ...
# Bangladesh             1
# Eritrea                1
# IS                     1
# Cuba                   1
# Česká republika        1
# Name: count, Length: 364, dtype: int64

# %% [markdown]
# Minimal cleanup on country has been done.

# %%
df.q1.value_counts()
# Out:
# q1
# 25-34         12668
# 35-44          9908
# 45-54          3193
# 18-24          1236
# 55-64           994
# 65 or over       95
# under 18         14
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# #### Reflection
# Write a short reflection (400-500 words) answering the following:
# - What were the biggest issues you encountered in the messy dataset?
# - How did cleaning the dataset improve its usability for machine learning?
# - What would happen if we trained a model on the messy dataset vs. the cleaned one?
# - Do you feel you skewed or biased the dataset while cleaning it?
#
# [Add you answer to this markdown cell]

# %% [markdown]
# One of the biggest issues with a dirty dataset is getting an accurate idea of what the counts are for each category.  For example, with the countries--I only did a base level cleanup on those and I still could have done a lot more.  The large number of nulls also make it difficult to assess the data for value.  Dirty data prevents the ML from being able to learn, as well.  Null isn't a value--it just doesn't exist.  The ML can't do anything with it.  The initial data set appeared to have at least one null in each record.  Moreover, various features contained a mixed bag of values--several different values for USA, including misspellings and added punctuation.  Some of the entries had extra spaces in the free form text entries.  This creates a skewed count and will create an erroneous result from the ML, because it will see each one as a distinct entity.
# <br>
# Removing the nulls and removing the columns that do not add value to the dataset, will improve the ML's ability to learn from the data. Without the nulls, the ML will be able to use all the columns to perform training and analytics.  However, given that the dataset shows a bias for whites, women, master's level education or higher, and for those in the US--this indicates that prior to training this dataset, the data person will need to add 'mock' data for men, for other races, other education levels and other nations based on the existing data.  If this is not done, the outcome of the ML will be bias and it will remain that way until the data is balanced.
#
# Anytime data is touched/updated/cleaned it does skew it.  Had the original dataset been used, much of it would have been useless for ML.  Cleaned, the ML now has more to work with.  The question is whether it skews it for better or worse.  The best thing to do when cleaning data is to make as little impact as possible, by imputing accurate values.  The drawback with this is that it can be excessively time consuming to impute every single questionable dirty value.

# %% [markdown]
# ## Deliverables
# Upload your Jupyter Notebook to your GitHub repo and then provide a link to that repo in Worlclass.

# %% [markdown]
# References used:
# Previous assignments from MSDS 600, 640 and 650
